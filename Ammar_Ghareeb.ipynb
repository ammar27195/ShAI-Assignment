# %%
# !wget -O Salaries.csv https://raw.githubusercontent.com/ammar27195/ShAI-Assignment/main/Salaries.csv
# Out:
# --2024-01-31 05:22:59--  https://raw.githubusercontent.com/ammar27195/ShAI-Assignment/main/Salaries.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16239776 (15M) [text/plain]
# Saving to: ‘Salaries.csv’
#
# Salaries.csv        100%[===================>]  15.49M  --.-KB/s    in 0.08s
#
# 2024-01-31 05:22:59 (182 MB/s) - ‘Salaries.csv’ saved [16239776/16239776]

# %% [markdown]
# **1- Basic Data Exploration: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.**

# %%
import pandas as pd
df = pd.read_csv('/content/Salaries.csv')
df.head()
num_rows, num_cols = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
print("\nData types of each column:")
print(df.dtypes)
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Number of rows: 148654
# Number of columns: 13
#
# Data types of each column:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object
#
# Missing values in each column:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# **2- Descriptive Statistics: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.**

# %%
# Calculate the mean salary
mean_salary = df['TotalPay'].mean()
print("Mean salary:", mean_salary)
# Out:
# Mean salary: 74768.32197169267

# %%
# Calculate the median salary
median_salary = df['TotalPay'].median()
print("Median salary:", median_salary)
# Out:
# Median salary: 71426.60999999999

# %%
# Calculate the mode for salaries
mode_salary = df['TotalPay'].mode()
print("Mode of salary:", mode_salary)
# Out:
# Mode of salary: 0    0.0
# Name: TotalPay, dtype: float64

# %%
# Calculate the minimum and maximum salary
min_salary = df['TotalPay'].min()
max_salary = df['TotalPay'].max()

print("Minimum salary:", min_salary)
print("Maximum salary:", max_salary)
# Out:
# Minimum salary: -618.13
# Maximum salary: 567595.43

# %%
# حساب نطاق الرواتب
salary_range = max_salary - min_salary
print("Salary Range:", salary_range)
# Out:
# Salary Range: 568213.56

# %%
# Calculate the standard deviation of the 'Salary' column
salary_std = df['TotalPay'].std()
print("Standard deviation of Salary:", salary_std)
# Out:
# Standard deviation of Salary: 50517.00527394987

# %% [markdown]
# **3- Data Cleaning: Handle missing data by suitable method with explain why you use it.**

# %% [markdown]
# To handle missing data in a DataFrame, there are several methods that can be used, such as:
#
# Dropping missing values: You can use the dropna() method to remove rows or columns with missing data. This method is suitable when the amount of missing data is relatively small and removing it won't significantly affect the analysis.

# %%
# Drop rows with missing values
df.dropna(inplace=True)

# %% [markdown]
# Imputation: Imputation involves replacing missing values with a suitable substitute, such as the mean, median, or mode of the column. This method is suitable when you want to retain as much data as possible while filling in the missing values with reasonable estimates.
# For example, to fill missing values with the mean of the column:

# %%
# Fill missing values with the mean
mean_salary = df['TotalPay'].mean()
df['TotalPay'].fillna(mean_salary, inplace=True)

# %% [markdown]
# The choice of method depends on the nature of the data and the impact of the missing values on the analysis. Dropping missing values is suitable when the amount of missing data is small and random, while imputation is suitable when retaining the data is important and the missing values can be reasonably estimated.

# %% [markdown]
# **4- Basic Data Visualization: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.**

# %%
# Create a histogram to visualize the distribution of salaries
plt.figure(figsize=(10, 6))
plt.hist(df['TotalPay'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a pie chart to represent the proportion of employees in different departments
dept_counts = df['JobTitle'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(dept_counts, labels=dept_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'orange'])
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %% [markdown]
# **5- Grouped Analysis: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.**

# %%
# Group the data by one column and calculate summary statistics for each group
grouped_data = df.groupby(['JobTitle'])
# Calculate the average salaries across different groups
average_salaries = grouped_data['TotalPay'].mean()
print(average_salaries)
# Out:
# JobTitle
# ACCOUNT CLERK                                     44035.664337
# ACCOUNTANT                                        47429.268000
# ACCOUNTANT INTERN                                 29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     67594.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             52705.880385
# X-Ray Laboratory Aide                             50823.942700
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.870000
# Youth Comm Advisor                                41414.307500
# ZOO CURATOR                                       66686.560000
# Name: TotalPay, Length: 2159, dtype: float64

# %% [markdown]
# **6- Simple Correlation Analysis: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.**

# %%
# Identify correlation between 'TotalPay -> salary' and 'Year' column
correlation = df['TotalPay'].corr(df['Year'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.03209039798559024

# %%
plt.scatter(df['TotalPay'], df['Year'])  # Replace 'Salary' and 'NumericalColumn' with the actual column names
plt.xlabel('Salary')
plt.ylabel('Year')
plt.title('Relationship between Salary and Year Column')
plt.show()

# %% [markdown]
# **7- Summary of Insights: Write a brief report summarizing the findings and insights from the analyses.**

# %% [markdown]
# **Introduction:**
#
# In this analysis, we explored several data analysis techniques to gain insights from a dataset. We performed basic data visualization, grouped analysis, and simple correlation analysis. Here is a summary of the findings and insights gathered from each analysis.
#
# 1. Basic Data Visualization:
# For the distribution of salaries, we created histograms or bar charts to visualize the data. This allowed us to understand the frequency distribution of salaries and identify any patterns or anomalies. Additionally, we used pie charts to represent the proportion of employees in different departments. This visual representation helped us understand the distribution of employees across various departments.
#
# 2. Grouped Analysis:
# Through grouped analysis, we grouped the data by one or more columns and calculated summary statistics for each group. By comparing the average salaries across different groups, we were able to identify variations in salaries based on specific categories such as departments or job titles. This provided insights into potential salary differences and helped in identifying any disparities among groups.
#
# 3. Simple Correlation Analysis:
# By conducting a correlation analysis between salary and another numerical column, we identified the relationship between these variables. The correlation coefficient indicated the strength and direction of the relationship. A positive correlation suggests that an increase in one variable is associated with an increase in the other, while a negative correlation indicates an inverse relationship. The scatter plot visualization further illustrated the nature of the relationship, highlighting any patterns or trends between the variables.
#
# **Insights:**
#
# Based on the analyses performed, the following insights were obtained:
#
# - Basic Data Visualization: The histograms or bar charts provided an overview of the salary distribution, highlighting any outliers or skewed patterns. The pie charts revealed the proportion of employees in different departments, giving a sense of the departmental structure within the organization.
#
# - Grouped Analysis: By comparing average salaries across different groups, we observed variations in salaries based on specific categories. This insight can be valuable for identifying potential factors influencing salary differences, such as departments or job titles.
#
# - Simple Correlation Analysis: The correlation coefficient helped us determine the strength and direction of the relationship between salary and another numerical column. The scatter plot visualization provided a visual representation of this relationship, helping to identify any linear or non-linear associations between the variables.
#
# **Conclusion:**
#
# In conclusion, the analyses conducted on the dataset provided valuable insights into the distribution of salaries, the proportion of employees in different departments, variations in salary across different groups, and the relationship between salary and another numerical column. These insights can guide decision-making processes, identify areas for further investigation, and contribute to a better understanding of the dataset under analysis. It is important to note that further analyses and considerations may be required to draw definitive conclusions or make informed decisions based on the specific context and objectives of the analysis.

# %% [markdown]
# Based on the analyses conducted, the following insights have been derived:
#
# 1. Proportion of Employees in Different Departments: A pie chart was used to represent the proportion of employees in different departments. This visualization provided a clear overview of the distribution of employees across various departments.
#
# 2. Average Salaries Across Different Groups: The average salaries were calculated for each department, revealing variations in compensation across different groups. This analysis helped in understanding the differences in average salaries among the departments.
#
# 3. Correlation Analysis: A correlation analysis was performed to identify any relationship between the 'salary' column and another numerical column. The correlation coefficient indicated the strength and direction of the relationship, providing valuable insights into the associations between these variables.
#
# 4. Visualization of Relationship: A scatter plot was created to visually represent the relationship between the 'salary' and another numerical column. This visualization facilitated a better understanding of the pattern or trend in the relationship between these variables.
#
# These analyses provided valuable insights into the distribution of employees, average salaries across departments, and the relationships between salary and other numerical variables, offering a comprehensive understanding of the dataset and its key attributes.
